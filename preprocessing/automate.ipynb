# %%
import pandas as pd
from automate_Nadhomi import preprocess_data
from joblib import dump, load
import numpy as np

# %%
# Memuat dataset
df = pd.read_csv("C:\Eksperimen_SML_Nadhomi\glass.csv")
df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# <>:2: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\DOMI\AppData\Local\Temp\ipykernel_640\2111041781.py:2: SyntaxWarning: invalid escape sequence '\E'
#   df = pd.read_csv("C:\Eksperimen_SML_Nadhomi\glass.csv")
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# ...

# %%
# Penerapan Fungsi preprocess_data
X_train, X_test, y_train, y_test = preprocess_data(df, 'Type', 'preprocess_pipeline.joblib', 'glass_preprocessing.csv')
# Out:
# Nama kolom berhasil disimpan ke: glass_preprocessing.csv

# %%
X_train
# Out:
# array([[-0.46437783, -0.63126753,  0.60181332, ..., -0.57906152,
#         -0.34220777, -0.56134932],
#        [ 0.78919945,  0.38134302,  0.58026489, ...,  0.32531334,
#         -0.34220777, -0.56134932],
#        [ 1.18659637,  1.31800777, -1.99836346, ...,  1.81157281,
#         -0.34220777,  0.2506997 ],
#        ...,
#        [-0.86177475, -0.340142  ,  0.45097434, ..., -0.3827631 ,
#         -0.34220777,  1.36726709],
#        [-0.00882526,  0.88764829, -0.42532833, ...,  0.26922808,
#         -0.34220777, -0.56134932],
#        [-0.11221308, -0.97302359, -0.01590823, ...,  0.33933466,
#         -0.34220777,  1.46877322]], shape=(149, 9))

# %%
y_train
# Out:
# 137    2
# 65     1
# 108    2
# 181    6
# 31     1
#       ..
# 106    2
# 14     1
# 92     2
# 179    6
# 102    2
# Name: Type, Length: 149, dtype: int64
